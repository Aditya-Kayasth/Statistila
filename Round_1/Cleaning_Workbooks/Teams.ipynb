# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
teams = pd.read_csv('/content/drive/MyDrive/Statistella/teams.csv')
teams[:5]
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LEAGUE_ID           30 non-null     int64
#  1   TEAM_ID             30 non-null     int64
#  2   MIN_YEAR            30 non-null     int64
#  3   MAX_YEAR            30 non-null     int64
#  4   ABBREVIATION        30 non-null     object
#  5   NICKNAME            30 non-null     object
#  6   YEARFOUNDED         30 non-null     int64
#  7   CITY                30 non-null     object
#  8   ARENA               30 non-null     object
#  9   ARENACAPACITY       26 non-null     float64
#  10  OWNER               30 non-null     object
#  11  GENERALMANAGER      30 non-null     object
#  12  HEADCOACH           30 non-null     object
#  13  DLEAGUEAFFILIATION  30 non-null     object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 3.4+ KB

# %%
teams.isna().sum()
# Out:
# LEAGUE_ID             0
# TEAM_ID               0
# MIN_YEAR              0
# MAX_YEAR              0
# ABBREVIATION          0
# NICKNAME              0
# YEARFOUNDED           0
# CITY                  0
# ARENA                 0
# ARENACAPACITY         4
# OWNER                 0
# GENERALMANAGER        0
# HEADCOACH             0
# DLEAGUEAFFILIATION    0
# dtype: int64

# %%
teams['LEAGUE_ID'].value_counts()
# Out:
# LEAGUE_ID
# 0    30
# Name: count, dtype: int64

# %%
teams.drop('LEAGUE_ID', axis=1, inplace=True)

# %%
type(teams['MIN_YEAR'][0])
# Out:
# numpy.int64

# %%
teams.drop('MAX_YEAR',inplace = True, axis=1)

# %%
teams.drop('MIN_YEAR',inplace = True, axis=1)

# %%
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TEAM_ID             30 non-null     int64
#  1   ABBREVIATION        30 non-null     object
#  2   NICKNAME            30 non-null     object
#  3   YEARFOUNDED         30 non-null     int64
#  4   CITY                30 non-null     object
#  5   ARENA               30 non-null     object
#  6   ARENACAPACITY       26 non-null     float64
#  7   OWNER               30 non-null     object
#  8   GENERALMANAGER      30 non-null     object
#  9   HEADCOACH           30 non-null     object
#  10  DLEAGUEAFFILIATION  30 non-null     object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 2.7+ KB

# %%
teams[['TEAM_ID','ABBREVIATION','NICKNAME','CITY']].nunique()
# Out:
# TEAM_ID         30
# ABBREVIATION    30
# NICKNAME        30
# CITY            29
# dtype: int64

# %%
teams
# Out:
#        TEAM_ID ABBREVIATION       NICKNAME  YEARFOUNDED           CITY  \
# 0   1610612737          ATL          Hawks         1949        Atlanta
# 1   1610612738          BOS        Celtics         1946         Boston
# 2   1610612740          NOP       Pelicans         2002    New Orleans
# 3   1610612741          CHI          Bulls         1966        Chicago
# 4   1610612742          DAL      Mavericks         1980         Dallas
# 5   1610612743          DEN        Nuggets         1976         Denver
# 6   1610612745          HOU        Rockets         1967        Houston
# 7   1610612746          LAC       Clippers         1970    Los Angeles
# 8   1610612747          LAL         Lakers         1948    Los Angeles
# 9   1610612748          MIA           Heat         1988          Miami
# 10  1610612749          MIL          Bucks         1968      Milwaukee
# 11  1610612750          MIN   Timberwolves         1989      Minnesota
# ...

# %%
teams.to_csv('processed_teams.csv', index=False)
